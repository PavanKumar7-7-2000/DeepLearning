# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
x_train = x_train.reshape(-1, 28*28).astype("float32") /255.0

# %%
x_test = x_test.reshape(-1, 28*28).astype("float32") /255.0

# %%
model = keras.Sequential(
    [
        layers.Dense(512, activation = 'relu'),
        layers.Dense(256, activation = 'relu'),
        layers.Dense(10),
    ]
)

# %%
model.compile(
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits = True),
    optimizer = keras.optimizers.Adam(learning_rate = 0.001),
    metrics = ["accuracy"],
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 535,818
# Trainable params: 535,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, batch_size = 32, epochs = 5, verbose = 2)
# Out:
# Epoch 1/5
# 1875/1875 - 12s - loss: 0.1898 - accuracy: 0.9427 - 12s/epoch - 6ms/step
# Epoch 2/5
# 1875/1875 - 11s - loss: 0.0788 - accuracy: 0.9744 - 11s/epoch - 6ms/step
# Epoch 3/5
# 1875/1875 - 11s - loss: 0.0541 - accuracy: 0.9827 - 11s/epoch - 6ms/step
# Epoch 4/5
# 1875/1875 - 11s - loss: 0.0427 - accuracy: 0.9864 - 11s/epoch - 6ms/step
# Epoch 5/5
# 1875/1875 - 11s - loss: 0.0325 - accuracy: 0.9892 - 11s/epoch - 6ms/step

# %%
model.evaluate(x_test, y_test, batch_size = 32, verbose = 2)
# Out:
# 313/313 - 1s - loss: 0.0697 - accuracy: 0.9818 - 1s/epoch - 4ms/step
# [0.06973206251859665, 0.9818000197410583]
